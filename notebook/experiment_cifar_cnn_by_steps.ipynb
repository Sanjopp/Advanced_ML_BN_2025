# %% [markdown]
# # Imports & setup

# %%
import sys
from pathlib import Path
sys.path.append(str(Path("..").resolve()))

from tqdm import trange
import torch
import matplotlib.pyplot as plt

from models.cnn import ConvMLP
from data import get_dataloaders
from train_utils import train_steps, evaluate

# %% [markdown]
# # Device & hyperparams

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
EPOCHS = 10
LR = 0.1

# %% [markdown]
# # Lancement des expériences

# %%
train_loader, test_loader = get_dataloaders()

results = {}

for use_bn in [False, True]:
    name = "BN" if use_bn else "NoBN"
    model = ConvMLP(in_channels=3, input_size=32, hidden_dims=(512, 256, 128), use_bn=use_bn).to(DEVICE)
    optimizer = torch.optim.SGD(model.parameters(), lr=LR)

    results[name] = {
        "loss": [],
        "grad_norm": [],
        "train_acc": [],
        "test_acc": []
    }

    for epoch in trange(EPOCHS, desc=f"Epochs ({name})"):
        train_steps(model, train_loader, optimizer, DEVICE, results[name])
        test_acc = evaluate(model, test_loader, DEVICE)
        results[name]["test_acc"].append(test_acc)
# Out:
# Epochs (NoBN):  10%|█         | 1/10 [00:10<01:37, 10.80s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 18
#      10 results[name] = {
#      11     "loss": [],
#      12     "grad_norm": [],
#      13     "train_acc": [],
#      14     "test_acc": []
#      15 }
#      17 for epoch in trange(EPOCHS, desc=f"Epochs ({name})"):
# ---> 18     train_steps(model, train_loader, optimizer, DEVICE, results[name])
#      19     test_acc = evaluate(model, test_loader, DEVICE)
#      20     results[name]["test_acc"].append(test_acc)
#
# File ~/Projectss/Advanced_ML_BN_2025/train_utils.py:26, in train_steps(model, loader, optimizer, device, history)
#      24 logits = model(x)
#      25 loss = F.cross_entropy(logits, y)
# ---> 26 loss.backward()
#      28 gnorm = grad_norm(model)
#      29 optimizer.step()
#
# File ~/Projectss/Advanced_ML_BN_2025/.venv/lib/python3.12/site-packages/torch/_tensor.py:625, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     615 if has_torch_function_unary(self):
#     616     return handle_torch_function(
#     617         Tensor.backward,
#     618         (self,),
#    (...)    623         inputs=inputs,
#     624     )
# --> 625 torch.autograd.backward(
#     626     self, gradient, retain_graph, create_graph, inputs=inputs
#     627 )
#
# File ~/Projectss/Advanced_ML_BN_2025/.venv/lib/python3.12/site-packages/torch/autograd/__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File ~/Projectss/Advanced_ML_BN_2025/.venv/lib/python3.12/site-packages/torch/autograd/graph.py:841, in _engine_run_backward(t_outputs, *args, **kwargs)
#     839     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840 try:
# --> 841     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842         t_outputs, *args, **kwargs
#     843     )  # Calls into the C++ engine to run the backward pass
#     844 finally:
#     845     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# # Plot loss

# %%
steps = range(1, len(results["NoBN"]["loss"]) + 1)

plt.plot(steps, results["NoBN"]["loss"], label="No BN", alpha=0.7)
plt.plot(steps, results["BN"]["loss"], label="With BN", alpha=0.7)
plt.xlabel("Step")
plt.ylabel("Training Loss")
plt.title("Training Loss per Step")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Plot accuracy

# %%
# We calculate number of steps
steps = range(1, len(results["NoBN"]["train_acc"]) + 1)
steps_per_epoch = len(results["NoBN"]["train_acc"]) // EPOCHS
test_steps = [(i + 1) * steps_per_epoch for i in range(EPOCHS)]

plt.plot(steps, results["NoBN"]["train_acc"], label="Train No BN", alpha=0.6)
plt.plot(steps, results["BN"]["train_acc"], label="Train BN", alpha=0.6)
plt.plot(test_steps, results["NoBN"]["test_acc"], marker='o', label="Test No BN", linewidth=2)
plt.plot(test_steps, results["BN"]["test_acc"], marker='o', label="Test BN", linewidth=2)
plt.xlabel("Step")
plt.ylabel("Accuracy")
plt.title("Train & Test Accuracy per Step")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Plot gradient norms

# %%
steps = range(1, len(results["NoBN"]["grad_norm"]) + 1)

plt.plot(steps, results["NoBN"]["grad_norm"], label="No BN", alpha=0.7)
plt.plot(steps, results["BN"]["grad_norm"], label="With BN", alpha=0.7)
plt.xlabel("Step")
plt.ylabel("Gradient Norm")
plt.title("Gradient Norm Evolution per Step")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## LR = 0.6 & 15 epochs

# %%
EPOCHS = 15
LR = 0.6
train_loader, test_loader = get_dataloaders()

results = {}

for use_bn in [False, True]:
    name = "BN" if use_bn else "NoBN"
    model = ConvMLP(in_channels=3, input_size=32, hidden_dims=(512, 256, 128), use_bn=use_bn).to(DEVICE)
    optimizer = torch.optim.SGD(model.parameters(), lr=LR)

    results[name] = {
        "loss": [],
        "grad_norm": [],
        "train_acc": [],
        "test_acc": []
    }

    for epoch in trange(EPOCHS, desc=f"Epochs ({name})"):
        train_steps(model, train_loader, optimizer, DEVICE, results[name])
        test_acc = evaluate(model, test_loader, DEVICE)
        results[name]["test_acc"].append(test_acc)
        
steps = range(1, len(results["NoBN"]["loss"]) + 1)

plt.plot(steps, results["NoBN"]["loss"], label="No BN", alpha=0.7)
plt.plot(steps, results["BN"]["loss"], label="With BN", alpha=0.7)
plt.xlabel("Step")
plt.ylabel("Training Loss")
plt.title("Training Loss per Step (LR=0.6)")
plt.legend()
plt.grid()
plt.show()

steps_per_epoch = len(results["NoBN"]["train_acc"]) // EPOCHS
test_steps = [(i + 1) * steps_per_epoch for i in range(EPOCHS)]

plt.plot(steps, results["NoBN"]["train_acc"], label="Train No BN", alpha=0.6)
plt.plot(steps, results["BN"]["train_acc"], label="Train BN", alpha=0.6)
plt.plot(test_steps, results["NoBN"]["test_acc"], marker='o', label="Test No BN", linewidth=2)
plt.plot(test_steps, results["BN"]["test_acc"], marker='o', label="Test BN", linewidth=2)
plt.xlabel("Step")
plt.ylabel("Accuracy")
plt.title("Train & Test Accuracy (LR=0.6)")
plt.legend()
plt.grid()
plt.show()

plt.plot(steps, results["NoBN"]["grad_norm"], label="No BN", alpha=0.7)
plt.plot(steps, results["BN"]["grad_norm"], label="With BN", alpha=0.7)
plt.xlabel("Step")
plt.ylabel("Gradient Norm")
plt.title("Gradient Norm Evolution per Step (LR=0.6)")
plt.legend()
plt.grid()
plt.show()
# Out:
# Epochs (NoBN): 100%|██████████| 15/15 [01:34<00:00,  6.31s/it]
# Epochs (BN): 100%|██████████| 15/15 [02:02<00:00,  8.17s/it]
